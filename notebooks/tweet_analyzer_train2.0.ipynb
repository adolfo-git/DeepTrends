# %%
""" from google.colab import drive
drive.mount('/content/drive') """

# %% [markdown]
# # Settings

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
#FOLDER_PATH = '/content/drive/MyDrive/Deep-Trends'
FOLDER_PATH = '../'
#BASE_MODEL = "vinai/bertweet-base"
BASE_MODEL = "dccuchile/bert-base-spanish-wwm-cased"
""" ID2LABEL = {
    0: "others",
    1: "joy",
    2: "sadness",
    3: "anger",
    4: "surprise",
    5: "disgust",
    6: "fear",
} """
ID2LABEL = {
    0: "NEG",
    1: "NEU",
    2: "POS"
}
LABEL2ID = {v: k for k, v in ID2LABEL.items()}
BATCH_SIZE = 32
EVAL_BATCH_SIZE = 16

# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, FOLDER_PATH)

# %%
"""
# !pip3 install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio===0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install numpy
# !pip install pandas==1.3.2
# !pip install datasets
# !pip install transformers
# !pip install emoji """

# %%
import torch
torch.cuda.is_available()

# %%
from bin.TweetAnalyzerTrainer import TweetAnalyzerTrainer

# %% [markdown]
# # Settings

# %% [markdown]
# # Train

# %%
t = TweetAnalyzerTrainer("es", ID2LABEL, LABEL2ID)

# %%
t.load_dataset("../datasets/no_emoticon_es.csv")

# %%
from bin.TweetAnalyzerTrainer import TweetAnalyzerTrainer
t.load_model(base_model=BASE_MODEL, max_length=128)

# %%
t.train()

# %%
t.evaluate()

# %%
t.save_model("../models/beto-sentiment-analysis")
